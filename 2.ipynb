# %%
import numpy as np
import matplotlib.pyplot as plt
import time

# %%
letters = 'ёйцукенгшщзхъфывапролджэячсмитьбю'
letters2 = [i+j for i in letters for j in letters]

# %%
letters_space = 'ёйцукенгшщзхъфывапролджэячсмитьбю '
letters2_space = [i+j for i in letters_space for j in letters_space]

# %%
wp = open('voyna-i-mir-tom-1.txt','r').readlines()
cdt = open('kapitanskaya-dochka.txt','r').readlines()

# %%
def count_freq(lines,symbols):
    freq = {}
    for i in symbols: freq[i] = 0
    num = 0
    
    for l in lines:
        l = l.lower()
        l = l.strip()
        for s in symbols:
            freq[s] += l.count(s)
            num += l.count(s)
            
    for s in freq:
        freq[s] /= num
    
    freq = {k: v for k, v in sorted(freq.items(), key=lambda item: item[1])[::-1]}
        
    return freq

# %%
def count_freq2(lines,symbols,low=True):
    freq = {}
    for i in symbols: freq[i] = 0
    num = 0
    
    for l in lines:
        if low: l = l.lower()
        for i in range(0,len(l),2):
            if l[i:i+2] in symbols:
                freq[l[i:i+2]] += 1
                num += 1
                  
    for s in freq:
        freq[s] /= num
    
    freq = {k: v for k, v in sorted(freq.items(), key=lambda item: item[1])[::-1]}
        
    return freq

# %%
wp_freq = count_freq(open('voyna-i-mir-tom-1.txt','r').readlines(),letters)
cd_freq = count_freq(open('kapitanskaya-dochka.txt','r').readlines(),letters)

# %%
wp_freq2 = count_freq2(open('voyna-i-mir-tom-1.txt','r').readlines(),letters2)
cd_freq2 = count_freq2(open('kapitanskaya-dochka.txt','r').readlines(),letters2)

# %% [markdown]
# # Составляем статистику частот

# %%
wp_freq
# Out:
# {'о': 0.11368425351950558,
#  'а': 0.08387404597867597,
#  'е': 0.07885400480097134,
#  'и': 0.06645056726094004,
#  'н': 0.06516213953263862,
#  'т': 0.05679478539509618,
#  'с': 0.0521738968997904,
#  'л': 0.05061627317638279,
#  'в': 0.04603622821136898,
#  'р': 0.045570240661219626,
#  'к': 0.03586061959635453,
#  'д': 0.030409864826479973,
#  'м': 0.029559576786765213,
#  'у': 0.02867030174086265,
#  'п': 0.025690580553652618,
#  'я': 0.02314899905502923,
#  'г': 0.02073366119549013,
#  'ь': 0.019476794376959792,
#  'ы': 0.018979245917039363,
#  'з': 0.01780777920730134,
#  'б': 0.017269387217088934,
#  'ч': 0.013628743448790568,
#  'й': 0.011519732066441284,
#  'ж': 0.010129195512409936,
#  'ш': 0.009444138117967255,
#  'х': 0.008530728258710346,
#  'ю': 0.006486695220007389,
#  'ц': 0.00404536602300976,
#  'э': 0.0030224212416061903,
#  'щ': 0.002805207921417048,
#  'ф': 0.002238968069641932,
#  'ё': 0.0008001618889018846,
#  'ъ': 0.0005253963214831399}

# %%
wp_freq2
# Out:
# {'то': 0.020166002318674568,
#  'ст': 0.015288471753278245,
#  'на': 0.015029814829355713,
#  'го': 0.01311298226814409,
#  'ал': 0.013015985921673141,
#  'но': 0.012567955178450184,
#  'ра': 0.012507909821111024,
#  'по': 0.012383200232791231,
#  'не': 0.012221539655339649,
#  'ко': 0.01219844528713228,
#  'ов': 0.011912075121360905,
#  'ка': 0.010951349403934357,
#  'во': 0.010327801462335395,
#  'тн': 0.0013625677242347682,
#  'дв': 0.0013487111033103467,
#  'см': 0.001344092229668873,
#  'еч': 0.001344092229668873,
#  'яс': 0.0012794279986882398,
#  'ял': 0.001251714756839397,
#  'оз': 0.0012424770095564495,
#  'ув': 0.0012424770095564495,
#  'ьс': 0.0012286203886320282,
#  'ву': 0.0012286203886320282,
#  'лк': 0.0012193826413490806,
#  'ае': 0.001214763767707607,
#  'гд': 0.001214763767707607,
#  'лю': 0.0011824316522172902,
#  'ыс': 0.0011778127785758165,
#  'тс': 0.001168575031292869,
#  'уз': 0.001163956157651395,
#  'рь': 0.0011593372840099214,
#  'зв': 0.0011316240421610786,
#  'ги': 0.0011316240421610786,
#  'пи': 0.0011270051685196049,
#  'аю': 0.001122386294878131,
#  'ап': 0.001122386294878131,
#  'сс': 0.0011177674212366573,
#  'ои': 0.0011177674212366573,
#  'бл': 0.0011131485475951834,
#  'ай': 0.0011085296739537097,
#  'уш': 0.0011039108003122358,
#  'гу': 0.0010992919266707621,
#  'сн': 0.0010669598111804454,
#  'ач': 0.0010623409375389717,
#  'йс': 0.001057722063897498,
#  'ою': 0.0010392465693316029,
#  'яд': 0.0010300088220486553,
#  'еш': 0.0010207710747657077,
#  'пл': 0.0010161522011242338,
#  'ещ': 0.0010161522011242338,
#  'рт': 0.0010022955801998125,
#  'би': 0.000993057832916865,
#  'ир': 0.0009838200856339173,
#  'уч': 0.0009838200856339173,
#  'зд': 0.0009792012119924434,
#  'рн': 0.0009745823383509697,
#  'зо': 0.0009699634647094959,
#  'ды': 0.0009653445910680221,
#  'аб': 0.0009653445910680221,
#  'фи': 0.0009653445910680221,
#  'щи': 0.0009607257174265483,
#  'су': 0.0009561068437850746,
#  'сё': 0.0009514879701436008,
#  'ии': 0.0009422502228606532,
#  'пу': 0.0009330124755777056,
#  'мы': 0.0009145369810118105,
#  'жд': 0.0009052992337288629,
#  'ца': 0.0008868237391629677,
#  'ян': 0.0008775859918800201,
#  'оя': 0.0008775859918800201,
#  'дл': 0.0008591104973141249,
#  'ур': 0.0008498727500311774,
#  'чу': 0.0008313972554652823,
#  'ыт': 0.0008313972554652823,
#  'зя': 0.0008036840136164395,
#  'уп': 0.0008036840136164395,
#  'нт': 0.0007990651399749657,
#  'цу': 0.0007944462663334919,
#  'иг': 0.0007805896454090705,
#  'фр': 0.0007805896454090705,
#  'пь': 0.0007759707717675967,
#  'ге': 0.0007759707717675967,
#  'нц': 0.0007713518981261229,
#  'ыб': 0.0007528764035602277,
#  'иб': 0.0007390197826358065,
#  'чн': 0.0007390197826358065,
#  'шл': 0.0007159254144284375,
#  'бя': 0.0007113065407869637,
#  'тя': 0.0007113065407869637,
#  'ох': 0.0007113065407869637,
#  'мя': 0.0006974499198625423,
#  'яж': 0.0006974499198625423,
#  'ют': 0.0006928310462210685,
#  'дь': 0.0006882121725795947,
#  'зы': 0.0006835932989381209,
#  'вз': 0.0006789744252966471,
#  'уб': 0.0006789744252966471,
#  'ке': 0.000660498930730752,
#  'ыш': 0.0006512611834478045,
#  'рю': 0.00027251354484695363,
#  'вт': 0.00027251354484695363,
#  'ык': 0.00026789467120547983,
#  'нч': 0.00026789467120547983,
#  'зс': 0.00026327579756400604,
#  'тч': 0.00025865692392253224,
#  'жу': 0.00025865692392253224,
#  'пы': 0.00025865692392253224,
#  'дц': 0.00025403805028105845,
#  'лч': 0.00025403805028105845,
#  'вь': 0.00025403805028105845,
#  'тд': 0.00024480030299811086,
#  'сх': 0.00024480030299811086,
#  'зб': 0.0002401814293566371,
#  'зл': 0.0002401814293566371,
#  'еи': 0.0002401814293566371,
#  'оо': 0.00023094368207368952,
#  'зк': 0.00023094368207368952,
#  'ъю': 0.00022632480843221573,
#  'уе': 0.00022632480843221573,
#  'лг': 0.00022170593479074193,
#  'нщ': 0.00022170593479074193,
#  'кв': 0.00022170593479074193,
#  'бщ': 0.00021708706114926813,
#  'вк': 0.00021708706114926813,
#  'хи': 0.00021708706114926813,
#  'зр': 0.00021708706114926813,
#  'ип': 0.00021246818750779434,
#  'ху': 0.00021246818750779434,
#  'сю': 0.00020784931386632057,
#  'хн': 0.00020784931386632057,
#  'юс': 0.00020323044022484677,
#  'ях': 0.00019861156658337298,
#  'зю': 0.00019861156658337298,
#  'шт': 0.00019861156658337298,
#  'ню': 0.00019861156658337298,
#  'ьб': 0.00019399269294189918,
#  'ощ': 0.00019399269294189918,
#  'рх': 0.00019399269294189918,
#  'пп': 0.00018937381930042539,
#  'аи': 0.00018937381930042539,
#  'ыч': 0.00018937381930042539,
#  'ьз': 0.00018475494565895162,
#  'вм': 0.00018475494565895162,
#  'вя': 0.00018013607201747782,
#  'фе': 0.00018013607201747782,
#  'хв': 0.00018013607201747782,
#  'цы': 0.00017551719837600403,
#  'тц': 0.00017089832473453023,
#  'ищ': 0.00016627945109305643,
#  'дш': 0.00016627945109305643,
#  'ып': 0.00016627945109305643,
#  'ьт': 0.00016166057745158267,
#  'яч': 0.00016166057745158267,
#  'мс': 0.00015242283016863507,
#  'ящ': 0.00015242283016863507,
#  'дм': 0.00015242283016863507,
#  'рц': 0.00015242283016863507,
#  'лл': 0.00014780395652716128,
#  'рб': 0.00014780395652716128,
#  'ыг': 0.00014780395652716128,
#  'гк': 0.00014780395652716128,
#  'йш': 0.00014780395652716128,
#  'дп': 0.0001431850828856875,
#  'лп': 0.0001385662092442137,
#  'оц': 0.0001385662092442137,
#  'ау': 0.0001385662092442137,
#  'юш': 0.00013394733560273992,
#  'тт': 0.00013394733560273992,
#  'яю': 0.00013394733560273992,
#  'эл': 0.00013394733560273992,
#  'ыд': 0.00013394733560273992,
#  'рч': 0.00012932846196126612,
#  'хр': 0.00012932846196126612,
#  'чо': 0.00012470958831979233,
#  'бъ': 0.00012009071467831854,
#  'яе': 0.00012009071467831854,
#  'ац': 0.00012009071467831854,
#  'фл': 0.00012009071467831854,
#  'уй': 0.00012009071467831854,
#  'юн': 0.00011547184103684476,
#  'мл': 0.00011547184103684476,
#  'мк': 0.00011547184103684476,
#  'рл': 0.00011547184103684476,
#  'ьи': 0.00011085296739537097,
#  'уэ': 4.6188736414737904e-05,
#  'юл': 4.156986277326411e-05,
#  'тх': 4.156986277326411e-05,
#  'яц': 4.156986277326411e-05,
#  'лб': 4.156986277326411e-05,
#  'хт': 4.156986277326411e-05,
#  'хе': 4.156986277326411e-05,
#  'зъ': 4.156986277326411e-05,
#  'уи': 4.156986277326411e-05,
#  'юз': 3.695098913179032e-05,
#  'тщ': 3.695098913179032e-05,
#  'мм': 3.695098913179032e-05,
#  'мц': 3.695098913179032e-05,
#  'рф': 3.695098913179032e-05,
#  'нж': 3.695098913179032e-05,
#  'кю': 3.695098913179032e-05,
#  'бч': 3.233211549031653e-05,
#  'иф': 3.233211549031653e-05,
#  'сц': 3.233211549031653e-05,
#  'жс': 3.233211549031653e-05,
#  'жг': 3.233211549031653e-05,
#  'дю': 3.233211549031653e-05,
#  'пг': 3.233211549031653e-05,
#  'гч': 3.233211549031653e-05,
#  'еф': 3.233211549031653e-05,
#  'цг': 3.233211549031653e-05,
#  'цн': 3.233211549031653e-05,
#  'бд': 2.771324184884274e-05,
#  'мь': 2.771324184884274e-05,
#  'мт': 2.771324184884274e-05,
#  'яи': 2.771324184884274e-05,
#  'яп': 2.771324184884274e-05,
#  'жю': 2.771324184884274e-05,
#  'дч': 2.771324184884274e-05,
#  'дд': 2.771324184884274e-05,
#  'вв': 2.771324184884274e-05,
#  'фы': 2.771324184884274e-05,
#  'цв': 2.771324184884274e-05,
#  'сф': 2.3094368207368952e-05,
#  'съ': 2.3094368207368952e-05,
#  'оэ': 2.3094368207368952e-05,
#  'пш': 2.3094368207368952e-05,
#  'въ': 2.3094368207368952e-05,
#  'вг': 2.3094368207368952e-05,
#  'зч': 2.3094368207368952e-05,
#  'зш': 2.3094368207368952e-05,
#  'шм': 2.3094368207368952e-05,
#  'шв': 2.3094368207368952e-05,
#  'нб': 2.3094368207368952e-05,
#  'нф': 2.3094368207368952e-05,
#  'кц': 2.3094368207368952e-05,
#  'бг': 1.847549456589516e-05,
#  'тэ': 1.847549456589516e-05,
#  'тф': 1.847549456589516e-05,
#  'тг': 1.847549456589516e-05,
#  'чр': 1.847549456589516e-05,
#  'жм': 1.847549456589516e-05,
#  'жж': 1.847549456589516e-05,
#  'дф': 1.847549456589516e-05,
#  'пч': 1.847549456589516e-05,
#  'вб': 1.847549456589516e-05,
#  'нв': 1.847549456589516e-05,
#  'кж': 1.847549456589516e-05,
#  'йо': 1.847549456589516e-05,
#  'бт': 1.385662092442137e-05,
#  'ьщ': 1.385662092442137e-05,
#  'тз': 1.385662092442137e-05,
#  'мш': 1.385662092442137e-05,
#  'яй': 1.385662092442137e-05,
#  'эп': 1.385662092442137e-05,
#  'дж': 1.385662092442137e-05,
#  'дз': 1.385662092442137e-05,
#  'лф': 1.385662092442137e-05,
#  'аа': 1.385662092442137e-05,
#  'вц': 1.385662092442137e-05,
#  'ыи': 1.385662092442137e-05,
#  'фт': 1.385662092442137e-05,
#  'зт': 1.385662092442137e-05,
#  'щь': 1.385662092442137e-05,
#  'нп': 1.385662092442137e-05,
#  'нз': 1.385662092442137e-05,
#  'еа': 1.385662092442137e-05,
#  'уо': 1.385662092442137e-05,
#  'уф': 1.385662092442137e-05,
#  'цл': 1.385662092442137e-05,
#  'юж': 9.23774728294758e-06,
#  'юх': 9.23774728294758e-06,
#  'юк': 9.23774728294758e-06,
#  'бю': 9.23774728294758e-06,
#  'бж': 9.23774728294758e-06,
#  'бц': 9.23774728294758e-06,
#  'ьф': 9.23774728294758e-06,
#  'сг': 9.23774728294758e-06,
#  'яш': 9.23774728294758e-06,
#  'эм': 9.23774728294758e-06,
#  'эг': 9.23774728294758e-06,
#  'дг': 9.23774728294758e-06,
#  'лв': 9.23774728294758e-06,
#  'лз': 9.23774728294758e-06,
#  'ао': 9.23774728294758e-06,
#  'ыу': 9.23774728294758e-06,
#  'фк': 9.23774728294758e-06,
#  'хъ': 9.23774728294758e-06,
#  'шр': 9.23774728294758e-06,
#  'нл': 9.23774728294758e-06,
#  'кч': 9.23774728294758e-06,
#  'кш': 9.23774728294758e-06,
#  'уа': 9.23774728294758e-06,
#  'ёр': 9.23774728294758e-06,
#  'бэ': 4.61887364147379e-06,
#  'бз': 4.61887364147379e-06,
#  'бш': 4.61887364147379e-06,
#  'ьв': 4.61887364147379e-06,
#  'тж': 4.61887364147379e-06,
#  'тё': 4.61887364147379e-06,
#  'мб': 4.61887364147379e-06,
#  'мэ': 4.61887364147379e-06,
#  'мз': 4.61887364147379e-06,
#  'мщ': 4.61887364147379e-06,
#  'яф': 4.61887364147379e-06,
#  'эд': 4.61887364147379e-06,
#  'эх': 4.61887364147379e-06,
#  'эш': 4.61887364147379e-06,
#  'эц': 4.61887364147379e-06,
#  'дэ': 4.61887364147379e-06,
#  'лщ': 4.61887364147379e-06,
#  'лё': 4.61887364147379e-06,
#  'рэ': 4.61887364147379e-06,
#  'пф': 4.61887364147379e-06,
#  'пц': 4.61887364147379e-06,
#  'аэ': 4.61887364147379e-06,
#  'вщ': 4.61887364147379e-06,
#  'фм': 4.61887364147379e-06,
#  'фс': 4.61887364147379e-06,
#  'фф': 4.61887364147379e-06,
#  'хп': 4.61887364147379e-06,
#  'зз': 4.61887364147379e-06,
#  'зц': 4.61887364147379e-06,
#  'шс': 4.61887364147379e-06,
#  'гм': 4.61887364147379e-06,
#  'гш': 4.61887364147379e-06,
#  'нэ': 4.61887364147379e-06,
#  'кз': 4.61887364147379e-06,
#  'кк': 4.61887364147379e-06,
#  'уц': 4.61887364147379e-06,
#  'йщ': 4.61887364147379e-06,
#  'йе': 4.61887364147379e-06,
#  'ёл': 4.61887364147379e-06,
#  'ёз': 4.61887364147379e-06,
#  'юь': 0.0,
#  'юи': 0.0,
#  'юя': 0.0,
#  'юэ': 0.0,
#  'юо': 0.0,
#  'юп': 0.0,
#  'юа': 0.0,
#  'юв': 0.0,
#  'юы': 0.0,
#  'юф': 0.0,
#  'юъ': 0.0,
#  'юг': 0.0,
#  'юе': 0.0,
#  'юу': 0.0,
#  'юй': 0.0,
#  'юё': 0.0,
#  'бп': 0.0,
#  'бф': 0.0,
#  'бй': 0.0,
#  'бё': 0.0,
#  'ьь': 0.0,
#  'ьэ': 0.0,
#  'ьж': 0.0,
#  'ьл': 0.0,
#  'ьр': 0.0,
#  'ьп': 0.0,
#  'ьа': 0.0,
#  'ьы': 0.0,
#  'ьъ': 0.0,
#  'ьх': 0.0,
#  'ьу': 0.0,
#  'ьй': 0.0,
#  'ьё': 0.0,
#  'тш': 0.0,
#  'тй': 0.0,
#  'иь': 0.0,
#  'иэ': 0.0,
#  'иы': 0.0,
#  'иъ': 0.0,
#  'иу': 0.0,
#  'иё': 0.0,
#  'мж': 0.0,
#  'мд': 0.0,
#  'мв': 0.0,
#  'мф': 0.0,
#  'мъ': 0.0,
#  'мх': 0.0,
#  'мй': 0.0,
#  'мё': 0.0,
#  'сэ': 0.0,
#  'сщ': 0.0,
#  'сй': 0.0,
#  'чю': 0.0,
#  'чб': 0.0,
#  'чм': 0.0,
#  'чс': 0.0,
#  'чч': 0.0,
#  'чя': 0.0,
#  'чэ': 0.0,
#  'чж': 0.0,
#  'чд': 0.0,
#  'чп': 0.0,
#  'чв': 0.0,
#  'чы': 0.0,
#  'чф': 0.0,
#  'чъ': 0.0,
#  'чх': 0.0,
#  'чз': 0.0,
#  'чщ': 0.0,
#  'чг': 0.0,
#  'чц': 0.0,
#  'чй': 0.0,
#  'чё': 0.0,
#  'яь': 0.0,
#  'яэ': 0.0,
#  'яо': 0.0,
#  'яа': 0.0,
#  'яы': 0.0,
#  'яъ': 0.0,
#  'яу': 0.0,
#  'яё': 0.0,
#  'эю': 0.0,
#  'эб': 0.0,
#  'эь': 0.0,
#  'эи': 0.0,
#  'эч': 0.0,
#  'эя': 0.0,
#  'ээ': 0.0,
#  'эж': 0.0,
#  'эо': 0.0,
#  'эа': 0.0,
#  'эв': 0.0,
#  'эы': 0.0,
#  'эф': 0.0,
#  'эъ': 0.0,
#  'эз': 0.0,
#  'эщ': 0.0,
#  'эе': 0.0,
#  'эу': 0.0,
#  'эй': 0.0,
#  'эё': 0.0,
#  'жт': 0.0,
#  'жя': 0.0,
#  'жэ': 0.0,
#  'жл': 0.0,
#  'жр': 0.0,
#  'жп': 0.0,
#  'жв': 0.0,
#  'жы': 0.0,
#  'жф': 0.0,
#  'жъ': 0.0,
#  'жх': 0.0,
#  'жз': 0.0,
#  'жщ': 0.0,
#  'жш': 0.0,
#  'жц': 0.0,
#  'жй': 0.0,
#  'жё': 0.0,
#  'дщ': 0.0,
#  'дй': 0.0,
#  'дё': 0.0,
#  'лм': 0.0,
#  'лэ': 0.0,
#  'лр': 0.0,
#  'лъ': 0.0,
#  'лх': 0.0,
#  'лш': 0.0,
#  'лц': 0.0,
#  'лй': 0.0,
#  'оь': 0.0,
#  'оа': 0.0,
#  'оы': 0.0,
#  'оъ': 0.0,
#  'оё': 0.0,
#  'ръ': 0.0,
#  'рй': 0.0,
#  'рё': 0.0,
#  'пю': 0.0,
#  'пб': 0.0,
#  'пм': 0.0,
#  'пс': 0.0,
#  'пэ': 0.0,
#  'пж': 0.0,
#  'пд': 0.0,
#  'пв': 0.0,
#  'пъ': 0.0,
#  'пх': 0.0,
#  'пз': 0.0,
#  'пщ': 0.0,
#  'пй': 0.0,
#  'пё': 0.0,
#  'аь': 0.0,
#  'аы': 0.0,
#  'аъ': 0.0,
#  'аё': 0.0,
#  'вю': 0.0,
#  'вэ': 0.0,
#  'вж': 0.0,
#  'вф': 0.0,
#  'вй': 0.0,
#  'вё': 0.0,
#  'ыю': 0.0,
#  'ыь': 0.0,
#  'ыя': 0.0,
#  'ыэ': 0.0,
#  'ыо': 0.0,
#  'ыа': 0.0,
#  'ыы': 0.0,
#  'ыф': 0.0,
#  'ыъ': 0.0,
#  'ыщ': 0.0,
#  'ыц': 0.0,
#  'ыё': 0.0,
#  'фю': 0.0,
#  'фб': 0.0,
#  'фь': 0.0,
#  'фч': 0.0,
#  'фя': 0.0,
#  'фэ': 0.0,
#  'фж': 0.0,
#  'фд': 0.0,
#  'фп': 0.0,
#  'фв': 0.0,
#  'фъ': 0.0,
#  'фх': 0.0,
#  'фз': 0.0,
#  'фщ': 0.0,
#  'фш': 0.0,
#  'фг': 0.0,
#  'фн': 0.0,
#  'фц': 0.0,
#  'фй': 0.0,
#  'фё': 0.0,
#  'ъб': 0.0,
#  'ъь': 0.0,
#  'ът': 0.0,
#  'ъи': 0.0,
#  'ъм': 0.0,
#  'ъс': 0.0,
#  'ъч': 0.0,
#  'ъэ': 0.0,
#  'ъж': 0.0,
#  'ъд': 0.0,
#  'ъл': 0.0,
#  'ъо': 0.0,
#  'ър': 0.0,
#  'ъп': 0.0,
#  'ъа': 0.0,
#  'ъв': 0.0,
#  'ъы': 0.0,
#  'ъф': 0.0,
#  'ъъ': 0.0,
#  'ъх': 0.0,
#  'ъз': 0.0,
#  'ъщ': 0.0,
#  'ъш': 0.0,
#  'ъг': 0.0,
#  'ън': 0.0,
#  'ък': 0.0,
#  'ъу': 0.0,
#  'ъц': 0.0,
#  'ъй': 0.0,
#  'ъё': 0.0,
#  'хю': 0.0,
#  'хб': 0.0,
#  'хь': 0.0,
#  'хч': 0.0,
#  'хя': 0.0,
#  'хэ': 0.0,
#  'хж': 0.0,
#  'хд': 0.0,
#  'хы': 0.0,
#  'хф': 0.0,
#  'хх': 0.0,
#  'хз': 0.0,
#  'хщ': 0.0,
#  'хш': 0.0,
#  'хг': 0.0,
#  'хк': 0.0,
#  'хц': 0.0,
#  'хй': 0.0,
#  'хё': 0.0,
#  'зэ': 0.0,
#  'зп': 0.0,
#  'зф': 0.0,
#  'зх': 0.0,
#  'зщ': 0.0,
#  'зй': 0.0,
#  'зё': 0.0,
#  'щю': 0.0,
#  'щб': 0.0,
#  'щт': 0.0,
#  'щм': 0.0,
#  'щс': 0.0,
#  'щч': 0.0,
#  'щя': 0.0,
#  'щэ': 0.0,
#  'щж': 0.0,
#  'щд': 0.0,
#  'щл': 0.0,
#  'що': 0.0,
#  'щр': 0.0,
#  'щп': 0.0,
#  'щв': 0.0,
#  'щы': 0.0,
#  'щф': 0.0,
#  'щъ': 0.0,
#  'щх': 0.0,
#  'щз': 0.0,
#  'щщ': 0.0,
#  'щш': 0.0,
#  'щг': 0.0,
#  'щк': 0.0,
#  'щц': 0.0,
#  'щй': 0.0,
#  'щё': 0.0,
#  'шю': 0.0,
#  'шб': 0.0,
#  'шч': 0.0,
#  'шя': 0.0,
#  'шэ': 0.0,
#  'шж': 0.0,
#  'шд': 0.0,
#  'шы': 0.0,
#  'шф': 0.0,
#  'шъ': 0.0,
#  'шх': 0.0,
#  'шз': 0.0,
#  'шщ': 0.0,
#  'шш': 0.0,
#  'шг': 0.0,
#  'шц': 0.0,
#  'шй': 0.0,
#  'шё': 0.0,
#  'гю': 0.0,
#  'гб': 0.0,
#  'гь': 0.0,
#  'гт': 0.0,
#  'гя': 0.0,
#  'гэ': 0.0,
#  'гж': 0.0,
#  'гп': 0.0,
#  'гы': 0.0,
#  'гф': 0.0,
#  'гъ': 0.0,
#  'гх': 0.0,
#  'гз': 0.0,
#  'гщ': 0.0,
#  'гг': 0.0,
#  'гц': 0.0,
#  'гй': 0.0,
#  'гё': 0.0,
#  'нм': 0.0,
#  'нъ': 0.0,
#  'нх': 0.0,
#  'нй': 0.0,
#  'нё': 0.0,
#  'еь': 0.0,
#  'еэ': 0.0,
#  'еы': 0.0,
#  'еъ': 0.0,
#  'её': 0.0,
#  'кб': 0.0,
#  ...}

# %% [markdown]
# ## Переводим. Зашифровывать не будем, сделаем вид, что русского не знаем.

# %% [markdown]
# ### Используя вычисленные частоты меняем буквы Капитанской Дочки на буквы с соответсвующей по порядку частотой в Войне и Мире

# %%
print('Совпавших частот символов в Войне и Мире и Капитанской Дочке:',len([i for i in range(len(letters)) if list(wp_freq.keys())[i] == list(cd_freq.keys())[i]]),'/',len(letters))
# Out:
# Совпавших частот символов в Войне и Мире и Капитанской Дочке: 15 / 33

# %%
for l in cdt[16:18]:
    ln = ''
    for i in range(len(l)):
        if l[i].lower() in letters:
            ln += list(wp_freq.keys())[list(cd_freq.keys()).index(l[i].lower())]
        else: ln += l[i]
            
    print(ln)
# Out:
#      отец кож ануреж петрович ыринев в колоуости своеж слмшил при ырафе киниюе, и взйел в отставдм прекгер-кажорок в 17.. ыоум. с тею пор шил он в своеж сикьирсдож уеревни, ыуе и шенился на уевице авуотги василгевне х., уочери ьеуноыо такойнеыо уворянина. нас ьзло уевятг человед уетеж. все кои ьратгя и сестрз мкерли во клауенчестве.
#
#      катмйда ьзла еэе кнох ьрхюата, дад мше я ьзл баписан в секеновсдиж полд сершанток, по килости каиора ываруии днябя ь., ьлибдоыо найеыо роуственнида. если ьз паче всядоыо чаяния катмйда роуила уочг, то ьатхйда оьёявил ьз дмуа слеуовало о скерти неявивйеыося сершанта и уело тек ьз и дончилосг. я считался в отпмсдм уо одончания намд. в то врекя воспитзвалисг кз не по нонейнекм. с пятилетнеыо вобраста отуан я ьзл на рмди стрекяннокм савелгичм, ба требвое повеуение пошалованнокм кне в уяугди. поу еыо науборок на увенауцаток ыоум взмчился я рмссдож ыракоте и коы оченг бураво смуитг о свож
#      Могзьов бвыа уче слжа бяхгиан, овк вше я аял ваопсон в ннодрамуейй нолд сатндядте, но мзаосбы маупра тпльари пярвя Б., укоекапо низмио водяобкоеров. сяло бы щети ввекапо чидеря тркрева воарли длсь, то усцуева сьдтавл ая кика менуолгоо о агатбы ниюаввпмиося ннеяриан и длао скм ая и княрыреин. Я счойгове в октбуож до твняимеря науз. В ал вроыб восопзннелоин мы ст по расткелеу. С пичзамостпо вькоттоа ортьн я аял на рузи тороыбхотеу соилегбоу, за амряене ноилакере нондренехотеу сле в ырачей. нод мио наьчпрте на вукоэтблалм погл вхерышия я пещикай лючеоре и дег лскоь гуотен сикойь о кувитонех беуйазо кадиаж. В озо зялея усцуева наивл ибя одив фотзееша, мостя Бятро, каалвопо влгсегои ое Москвы схсяск с гомолек зтсдате вдоа и онолриемазо трмеа. Птаряд мио днегра не ноячесзаве Сеслаьнсс. "Слине базу" - впримл ня пво стуя - "кувмове, аррж уехт, птатисон, нетпрдмко. ожть кет нвшра тотбыни лдыере акплуп, и наертрни мбутя, овк ийфео и купах оиакй ст санре!"

# %% [markdown]
# # Применим MCMC-сэмплирование

# %% [markdown]
# #### Распределение в пространстве перестановок будет выглядеть так:
# #### p( длина перестановки = i ) * p( переставлены элементы x1 и x2)

# %%
def my_distribution1(l,probs1):
    sample = np.random.choice(np.append(np.arange(l),[0]),p = probs1)
    return sample

# %%
def my_distribution2(ar,probs2,num_transpose=0):
    ar = np.array(ar)
    transpositions = [np.where(ar == i)[0][0] for i in np.random.choice(ar,num_transpose*2,False,p = probs2)]
    transpositions = np.resize(transpositions,(num_transpose,2))
    return transpositions

# %%
def find_probs_for_dists(p,l,ar,ar_probs):
    probs1 = (1/p-1)*p**(np.arange(l)+1)
    probs1 = np.append(probs1,1-np.sum(probs1))
    
#     probs2 = ar_probs
    
    q = sum([1/i for i in ar_probs if i != 0])
    probs2 = [(1/i)/q for i in ar_probs if i != 0]
    probs2 += [0]*ar_probs.count(0)
    
    #probs2[0] += 1-sum(probs2)
    return probs1,probs2

# %%
def my_MCMC(orig,orig_probs,num_sampl,p=1/2,l=10,step=100,walk=10):
    orig = np.array(orig)
    c = np.arange(len(orig))
    probs1,probs2 = find_probs_for_dists(p,l,orig,orig_probs)
    res = []
    
    #сначала погуляем немного, потом посэмплируем
    for i in range(num_sampl+walk):
        for j in range(step):
        
            num_transpose = my_distribution1(l,probs1)
            distance1 = len([i for i in range(len(c)) if c[i] != i])
            c_c = c
            
            if num_transpose == 0:
                continue
                
            where = 1
            transpositions = my_distribution2(orig,probs2,num_transpose)
            for t in transpositions:
                c_c[t] = c_c[[t[1],t[0]]]
                where *= 2*(1-orig_probs[t[0]])*(1-orig_probs[t[0]])
                
            distance2 = len([i for i in range(len(c)) if c_c[i] != i])
            
            how_many = ((1/p-1)*p**(distance2+1))/((1/p-1)*p**(distance1+1))
            a = how_many*where
            x = np.random.random()
            if x < a:
                c = c_c
        if i >= walk:
            res += [orig[c]]
    
    return res

# %%
k = 0
for l in cdt[16:18]:
    for i in range(0,len(l),2):
        k += 1

# %%
cd_freq2_perms = my_MCMC(list(cd_freq2.keys()),list(cd_freq2.values()),k,1/2,5,100,10)

# %%
ln1 = ''
for l in cdt[16:18]:
    for i in range(0,len(l),2):
        if l[i:i+2].lower() in letters2:
            ln1 += list(wp_freq2.keys())[list(cd_freq2.keys()).index(l[i:i+2].lower())]
# %%
m_freq2
# Out:
# {'ႨႲ': 0.034782608695652174,
#  'ႩႹ': 0.02608695652173913,
#  'Ⴜჰ': 0.02608695652173913,
#  'დႨ': 0.02608695652173913,
#  'Ⴃჵ': 0.02608695652173913,
#  'Ⴈჳ': 0.02608695652173913,
#  'შჂ': 0.017391304347826087,
#  'ႽႨ': 0.017391304347826087,
#  'ის': 0.017391304347826087,
#  'ႹႭ': 0.017391304347826087,
#  'Ⴙჲ': 0.017391304347826087,
#  'ႹႨ': 0.017391304347826087,
#  'ჂႨ': 0.017391304347826087,
#  'სႹ': 0.017391304347826087,
#  'ქႹ': 0.017391304347826087,
#  'ჾႣ': 0.017391304347826087,
#  'დქ': 0.017391304347826087,
#  'ჵი': 0.017391304347826087,
#  'ჵჂ': 0.017391304347826087,
#  'ႨႩ': 0.017391304347826087,
#  'Ⴈშ': 0.017391304347826087,
#  'Ⴈს': 0.017391304347826087,
#  'Ⴉჳ': 0.008695652173913044,
#  'ჇႭ': 0.008695652173913044,
#  'ჇႧ': 0.008695652173913044,
#  'შႼ': 0.008695652173913044,
#  'შჳ': 0.008695652173913044,
#  'შდ': 0.008695652173913044,
#  'ႼႨ': 0.008695652173913044,
#  'ႭႹ': 0.008695652173913044,
#  'Ⴍჲ': 0.008695652173913044,
#  'Ⴍჾ': 0.008695652173913044,
#  'Ⴍდ': 0.008695652173913044,
#  'ႭႣ': 0.008695652173913044,
#  'ႹႹ': 0.008695652173913044,
#  'Ⴙჳ': 0.008695652173913044,
#  'Ⴙჱ': 0.008695652173913044,
#  'Ⴙდ': 0.008695652173913044,
#  'Ⴙჵ': 0.008695652173913044,
#  'ჳჲ': 0.008695652173913044,
#  'ჳდ': 0.008695652173913044,
#  'ჳႣ': 0.008695652173913044,
#  'ჰႨ': 0.008695652173913044,
#  'ჱჶ': 0.008695652173913044,
#  'ჂႽ': 0.008695652173913044,
#  'Ⴢჲ': 0.008695652173913044,
#  'Ⴢჾ': 0.008695652173913044,
#  'Ⴢდ': 0.008695652173913044,
#  'Ⴢჵ': 0.008695652173913044,
#  'სႼ': 0.008695652173913044,
#  'სჂ': 0.008695652173913044,
#  'სდ': 0.008695652173913044,
#  'ႧჂ': 0.008695652173913044,
#  'Ⴇს': 0.008695652173913044,
#  'Ⴇჲ': 0.008695652173913044,
#  'Ⴇდ': 0.008695652173913044,
#  'ეႣ': 0.008695652173913044,
#  'ჲი': 0.008695652173913044,
#  'ჲႹ': 0.008695652173913044,
#  'ჲდ': 0.008695652173913044,
#  'ჲႣ': 0.008695652173913044,
#  'ხჂ': 0.008695652173913044,
#  'ხს': 0.008695652173913044,
#  'ხდ': 0.008695652173913044,
#  'ႲႹ': 0.008695652173913044,
#  'დႩ': 0.008695652173913044,
#  'დჳ': 0.008695652173913044,
#  'დს': 0.008695652173913044,
#  'დჲ': 0.008695652173913044,
#  'დჶ': 0.008695652173913044,
#  'დდ': 0.008695652173913044,
#  'Ⴃნ': 0.008695652173913044,
#  'Ⴃს': 0.008695652173913044,
#  'Ⴃხ': 0.008695652173913044,
#  'ჵდ': 0.008695652173913044,
#  'ჵႣ': 0.008695652173913044,
#  'ჵႨ': 0.008695652173913044,
#  'ႨჇ': 0.008695652173913044,
#  'ႨႾ': 0.008695652173913044,
#  'Ⴈჱ': 0.008695652173913044,
#  'ႨჂ': 0.008695652173913044,
#  'ႨႠ': 0.008695652173913044,
#  'ႨႧ': 0.008695652173913044,
#  'Ⴈე': 0.008695652173913044,
#  'Ⴈჲ': 0.008695652173913044,
#  'Ⴈჵ': 0.008695652173913044,
#  'ႩႩ': 0.0,
#  'ႩჇ': 0.0,
#  'Ⴉშ': 0.0,
#  'ႩႼ': 0.0,
#  'ႩႽ': 0.0,
#  'ႩႭ': 0.0,
#  'Ⴉი': 0.0,
#  'Ⴉჰ': 0.0,
#  'ႩႾ': 0.0,
#  'Ⴉჱ': 0.0,
#  'Ⴉნ': 0.0,
#  'ႩჂ': 0.0,
#  'ႩႠ': 0.0,
#  'Ⴉს': 0.0,
#  'ႩႧ': 0.0,
#  'Ⴉე': 0.0,
#  'Ⴉქ': 0.0,
#  'Ⴉჲ': 0.0,
#  'Ⴉჶ': 0.0,
#  'Ⴉჾ': 0.0,
#  'Ⴉხ': 0.0,
#  'ႩႲ': 0.0,
#  'Ⴉდ': 0.0,
#  'ႩႣ': 0.0,
#  'Ⴉჵ': 0.0,
#  'ႩႨ': 0.0,
#  'ჇႩ': 0.0,
#  'ჇჇ': 0.0,
#  'Ⴧშ': 0.0,
#  'ჇႼ': 0.0,
#  'ჇႽ': 0.0,
#  'Ⴧი': 0.0,
#  'ჇႹ': 0.0,
#  'Ⴧჳ': 0.0,
#  'Ⴧჰ': 0.0,
#  'ჇႾ': 0.0,
#  'Ⴧჱ': 0.0,
#  'Ⴧნ': 0.0,
#  'ჇჂ': 0.0,
#  'ჇႠ': 0.0,
#  'Ⴧს': 0.0,
#  'Ⴧე': 0.0,
#  'Ⴧქ': 0.0,
#  'Ⴧჲ': 0.0,
#  'Ⴧჶ': 0.0,
#  'Ⴧჾ': 0.0,
#  'Ⴧხ': 0.0,
#  'ჇႲ': 0.0,
#  'Ⴧდ': 0.0,
#  'ჇႣ': 0.0,
#  'Ⴧჵ': 0.0,
#  'ჇႨ': 0.0,
#  'შႩ': 0.0,
#  'შჇ': 0.0,
#  'შშ': 0.0,
#  'შႽ': 0.0,
#  'შႭ': 0.0,
#  'ში': 0.0,
#  'შႹ': 0.0,
#  'შჰ': 0.0,
#  'შႾ': 0.0,
#  'შჱ': 0.0,
#  'შნ': 0.0,
#  'შႠ': 0.0,
#  'შს': 0.0,
#  'შႧ': 0.0,
#  'შე': 0.0,
#  'შქ': 0.0,
#  'შჲ': 0.0,
#  'შჶ': 0.0,
#  'შჾ': 0.0,
#  'შხ': 0.0,
#  'შႲ': 0.0,
#  'შႣ': 0.0,
#  'შჵ': 0.0,
#  'შႨ': 0.0,
#  'ႼႩ': 0.0,
#  'ႼჇ': 0.0,
#  'Ⴜშ': 0.0,
#  'ႼႼ': 0.0,
#  'ႼႽ': 0.0,
#  'ႼႭ': 0.0,
#  'Ⴜი': 0.0,
#  'ႼႹ': 0.0,
#  'Ⴜჳ': 0.0,
#  'ႼႾ': 0.0,
#  'Ⴜჱ': 0.0,
#  'Ⴜნ': 0.0,
#  'ႼჂ': 0.0,
#  'ႼႠ': 0.0,
#  'Ⴜს': 0.0,
#  'ႼႧ': 0.0,
#  'Ⴜე': 0.0,
#  'Ⴜქ': 0.0,
#  'Ⴜჲ': 0.0,
#  'Ⴜჶ': 0.0,
#  'Ⴜჾ': 0.0,
#  'Ⴜხ': 0.0,
#  'ႼႲ': 0.0,
#  'Ⴜდ': 0.0,
#  'ႼႣ': 0.0,
#  'Ⴜჵ': 0.0,
#  'ႽႩ': 0.0,
#  'ႽჇ': 0.0,
#  'Ⴝშ': 0.0,
#  'ႽႼ': 0.0,
#  'ႽႽ': 0.0,
#  'ႽႭ': 0.0,
#  'Ⴝი': 0.0,
#  'ႽႹ': 0.0,
#  'Ⴝჳ': 0.0,
#  'Ⴝჰ': 0.0,
#  'ႽႾ': 0.0,
#  'Ⴝჱ': 0.0,
#  'Ⴝნ': 0.0,
#  'ႽჂ': 0.0,
#  'ႽႠ': 0.0,
#  'Ⴝს': 0.0,
#  'ႽႧ': 0.0,
#  'Ⴝე': 0.0,
#  'Ⴝქ': 0.0,
#  'Ⴝჲ': 0.0,
#  'Ⴝჶ': 0.0,
#  'Ⴝჾ': 0.0,
#  'Ⴝხ': 0.0,
#  'ႽႲ': 0.0,
#  'Ⴝდ': 0.0,
#  'ႽႣ': 0.0,
#  'Ⴝჵ': 0.0,
#  'ႭႩ': 0.0,
#  'ႭჇ': 0.0,
#  'Ⴍშ': 0.0,
#  'ႭႼ': 0.0,
#  'ႭႽ': 0.0,
#  'ႭႭ': 0.0,
#  'Ⴍი': 0.0,
#  'Ⴍჳ': 0.0,
#  'Ⴍჰ': 0.0,
#  'ႭႾ': 0.0,
#  'Ⴍჱ': 0.0,
#  'Ⴍნ': 0.0,
#  'ႭჂ': 0.0,
#  'ႭႠ': 0.0,
#  'Ⴍს': 0.0,
#  'ႭႧ': 0.0,
#  'Ⴍე': 0.0,
#  'Ⴍქ': 0.0,
#  'Ⴍჶ': 0.0,
#  'Ⴍხ': 0.0,
#  'ႭႲ': 0.0,
#  'Ⴍჵ': 0.0,
#  'ႭႨ': 0.0,
#  'იႩ': 0.0,
#  'იჇ': 0.0,
#  'იშ': 0.0,
#  'იႼ': 0.0,
#  'იႽ': 0.0,
#  'იႭ': 0.0,
#  'იი': 0.0,
#  'იႹ': 0.0,
#  'იჳ': 0.0,
#  'იჰ': 0.0,
#  'იႾ': 0.0,
#  'იჱ': 0.0,
#  'ინ': 0.0,
#  'იჂ': 0.0,
#  'იႠ': 0.0,
#  'იႧ': 0.0,
#  'იე': 0.0,
#  'იქ': 0.0,
#  'იჲ': 0.0,
#  'იჶ': 0.0,
#  'იჾ': 0.0,
#  'იხ': 0.0,
#  'იႲ': 0.0,
#  'იდ': 0.0,
#  'იႣ': 0.0,
#  'იჵ': 0.0,
#  'იႨ': 0.0,
#  'ႹႩ': 0.0,
#  'ႹჇ': 0.0,
#  'Ⴙშ': 0.0,
#  'ႹႼ': 0.0,
#  'ႹႽ': 0.0,
#  'Ⴙი': 0.0,
#  'Ⴙჰ': 0.0,
#  'ႹႾ': 0.0,
#  'Ⴙნ': 0.0,
#  'ႹჂ': 0.0,
#  'ႹႠ': 0.0,
#  'Ⴙს': 0.0,
#  'ႹႧ': 0.0,
#  'Ⴙე': 0.0,
#  'Ⴙქ': 0.0,
#  'Ⴙჶ': 0.0,
#  'Ⴙჾ': 0.0,
#  'Ⴙხ': 0.0,
#  'ႹႲ': 0.0,
#  'ႹႣ': 0.0,
#  'ჳႩ': 0.0,
#  'ჳჇ': 0.0,
#  'ჳშ': 0.0,
#  'ჳႼ': 0.0,
#  'ჳႽ': 0.0,
#  'ჳႭ': 0.0,
#  'ჳი': 0.0,
#  'ჳႹ': 0.0,
#  'ჳჳ': 0.0,
#  'ჳჰ': 0.0,
#  'ჳႾ': 0.0,
#  'ჳჱ': 0.0,
#  'ჳნ': 0.0,
#  'ჳჂ': 0.0,
#  'ჳႠ': 0.0,
#  'ჳს': 0.0,
#  'ჳႧ': 0.0,
#  'ჳე': 0.0,
#  'ჳქ': 0.0,
#  'ჳჶ': 0.0,
#  'ჳჾ': 0.0,
#  'ჳხ': 0.0,
#  'ჳႲ': 0.0,
#  'ჳჵ': 0.0,
#  'ჳႨ': 0.0,
#  'ჰႩ': 0.0,
#  'ჰჇ': 0.0,
#  'ჰშ': 0.0,
#  'ჰႼ': 0.0,
#  'ჰႽ': 0.0,
#  'ჰႭ': 0.0,
#  'ჰი': 0.0,
#  'ჰႹ': 0.0,
#  'ჰჳ': 0.0,
#  'ჰჰ': 0.0,
#  'ჰႾ': 0.0,
#  'ჰჱ': 0.0,
#  'ჰნ': 0.0,
#  'ჰჂ': 0.0,
#  'ჰႠ': 0.0,
#  'ჰს': 0.0,
#  'ჰႧ': 0.0,
#  'ჰე': 0.0,
#  'ჰქ': 0.0,
#  'ჰჲ': 0.0,
#  'ჰჶ': 0.0,
#  'ჰჾ': 0.0,
#  'ჰხ': 0.0,
#  'ჰႲ': 0.0,
#  'ჰდ': 0.0,
#  'ჰႣ': 0.0,
#  'ჰჵ': 0.0,
#  'ႾႩ': 0.0,
#  'ႾჇ': 0.0,
#  'Ⴞშ': 0.0,
#  'ႾႼ': 0.0,
#  'ႾႽ': 0.0,
#  'ႾႭ': 0.0,
#  'Ⴞი': 0.0,
#  'ႾႹ': 0.0,
#  'Ⴞჳ': 0.0,
#  'Ⴞჰ': 0.0,
#  'ႾႾ': 0.0,
#  'Ⴞჱ': 0.0,
#  'Ⴞნ': 0.0,
#  'ႾჂ': 0.0,
#  'ႾႠ': 0.0,
#  'Ⴞს': 0.0,
#  'ႾႧ': 0.0,
#  'Ⴞე': 0.0,
#  'Ⴞქ': 0.0,
#  'Ⴞჲ': 0.0,
#  'Ⴞჶ': 0.0,
#  'Ⴞჾ': 0.0,
#  'Ⴞხ': 0.0,
#  'ႾႲ': 0.0,
#  'Ⴞდ': 0.0,
#  'ႾႣ': 0.0,
#  'Ⴞჵ': 0.0,
#  'ႾႨ': 0.0,
#  'ჱႩ': 0.0,
#  'ჱჇ': 0.0,
#  'ჱშ': 0.0,
#  'ჱႼ': 0.0,
#  'ჱႽ': 0.0,
#  'ჱႭ': 0.0,
#  'ჱი': 0.0,
#  'ჱႹ': 0.0,
#  'ჱჳ': 0.0,
#  'ჱჰ': 0.0,
#  'ჱႾ': 0.0,
#  'ჱჱ': 0.0,
#  'ჱნ': 0.0,
#  'ჱჂ': 0.0,
#  'ჱႠ': 0.0,
#  'ჱს': 0.0,
#  'ჱႧ': 0.0,
#  'ჱე': 0.0,
#  'ჱქ': 0.0,
#  'ჱჲ': 0.0,
#  'ჱჾ': 0.0,
#  'ჱხ': 0.0,
#  'ჱႲ': 0.0,
#  'ჱდ': 0.0,
#  'ჱႣ': 0.0,
#  'ჱჵ': 0.0,
#  'ჱႨ': 0.0,
#  'ნႩ': 0.0,
#  'ნჇ': 0.0,
#  'ნშ': 0.0,
#  'ნႼ': 0.0,
#  'ნႽ': 0.0,
#  'ნႭ': 0.0,
#  'ნი': 0.0,
#  'ნႹ': 0.0,
#  'ნჳ': 0.0,
#  'ნჰ': 0.0,
#  'ნႾ': 0.0,
#  'ნჱ': 0.0,
#  'ნნ': 0.0,
#  'ნჂ': 0.0,
#  'ნႠ': 0.0,
#  'ნს': 0.0,
#  'ნႧ': 0.0,
#  'ნე': 0.0,
#  'ნქ': 0.0,
#  'ნჲ': 0.0,
#  'ნჶ': 0.0,
#  'ნჾ': 0.0,
#  'ნხ': 0.0,
#  'ნႲ': 0.0,
#  'ნდ': 0.0,
#  'ნႣ': 0.0,
#  'ნჵ': 0.0,
#  'ნႨ': 0.0,
#  'ჂႩ': 0.0,
#  'ჂჇ': 0.0,
#  'Ⴢშ': 0.0,
#  'ჂႼ': 0.0,
#  'ჂႭ': 0.0,
#  'Ⴢი': 0.0,
#  'ჂႹ': 0.0,
#  'Ⴢჳ': 0.0,
#  'Ⴢჰ': 0.0,
#  'ჂႾ': 0.0,
#  'Ⴢჱ': 0.0,
#  'Ⴢნ': 0.0,
#  'ჂჂ': 0.0,
#  'ჂႠ': 0.0,
#  'Ⴢს': 0.0,
#  'ჂႧ': 0.0,
#  'Ⴢე': 0.0,
#  'Ⴢქ': 0.0,
#  'Ⴢჶ': 0.0,
#  'Ⴢხ': 0.0,
#  'ჂႲ': 0.0,
#  'ჂႣ': 0.0,
#  'ႠႩ': 0.0,
#  'ႠჇ': 0.0,
#  'Ⴀშ': 0.0,
#  'ႠႼ': 0.0,
#  'ႠႽ': 0.0,
#  'ႠႭ': 0.0,
#  'Ⴀი': 0.0,
#  'ႠႹ': 0.0,
#  'Ⴀჳ': 0.0,
#  'Ⴀჰ': 0.0,
#  'ႠႾ': 0.0,
#  'Ⴀჱ': 0.0,
#  'Ⴀნ': 0.0,
#  'ႠჂ': 0.0,
#  'ႠႠ': 0.0,
#  'Ⴀს': 0.0,
#  'ႠႧ': 0.0,
#  'Ⴀე': 0.0,
#  'Ⴀქ': 0.0,
#  'Ⴀჲ': 0.0,
#  'Ⴀჶ': 0.0,
#  'Ⴀჾ': 0.0,
#  'Ⴀხ': 0.0,
#  'ႠႲ': 0.0,
#  'Ⴀდ': 0.0,
#  'ႠႣ': 0.0,
#  'Ⴀჵ': 0.0,
#  'ႠႨ': 0.0,
#  'სႩ': 0.0,
#  'სჇ': 0.0,
#  'სშ': 0.0,
#  'სႽ': 0.0,
#  'სႭ': 0.0,
#  'სი': 0.0,
#  'სჳ': 0.0,
#  'სჰ': 0.0,
#  'სႾ': 0.0,
#  'სჱ': 0.0,
#  'სნ': 0.0,
#  'სႠ': 0.0,
#  'სს': 0.0,
#  'სႧ': 0.0,
#  'სე': 0.0,
#  'სქ': 0.0,
#  'სჲ': 0.0,
#  'სჶ': 0.0,
#  'სჾ': 0.0,
#  'სხ': 0.0,
#  'სႲ': 0.0,
#  'სႣ': 0.0,
#  'სჵ': 0.0,
#  'სႨ': 0.0,
#  'ႧႩ': 0.0,
#  'ႧჇ': 0.0,
#  'Ⴇშ': 0.0,
#  'ႧႼ': 0.0,
#  'ႧႽ': 0.0,
#  'ႧႭ': 0.0,
#  'Ⴇი': 0.0,
#  'ႧႹ': 0.0,
#  'Ⴇჳ': 0.0,
#  'Ⴇჰ': 0.0,
#  'ႧႾ': 0.0,
#  'Ⴇჱ': 0.0,
#  'Ⴇნ': 0.0,
#  'ႧႠ': 0.0,
#  'ႧႧ': 0.0,
#  'Ⴇე': 0.0,
#  'Ⴇქ': 0.0,
#  'Ⴇჶ': 0.0,
#  'Ⴇჾ': 0.0,
#  'Ⴇხ': 0.0,
#  'ႧႲ': 0.0,
#  'ႧႣ': 0.0,
#  'Ⴇჵ': 0.0,
#  'ႧႨ': 0.0,
#  'ეႩ': 0.0,
#  'ეჇ': 0.0,
#  'ეშ': 0.0,
#  'ეႼ': 0.0,
#  'ეႽ': 0.0,
#  'ეႭ': 0.0,
#  'ეი': 0.0,
#  'ეႹ': 0.0,
#  'ეჳ': 0.0,
#  'ეჰ': 0.0,
#  'ეႾ': 0.0,
#  'ეჱ': 0.0,
#  'ენ': 0.0,
#  'ეჂ': 0.0,
#  'ეႠ': 0.0,
#  'ეს': 0.0,
#  'ეႧ': 0.0,
#  'ეე': 0.0,
#  'ექ': 0.0,
#  'ეჲ': 0.0,
#  'ეჶ': 0.0,
#  'ეჾ': 0.0,
#  'ეხ': 0.0,
#  'ეႲ': 0.0,
#  'ედ': 0.0,
#  'ეჵ': 0.0,
#  'ეႨ': 0.0,
#  'ქႩ': 0.0,
#  'ქჇ': 0.0,
#  'ქშ': 0.0,
#  'ქႼ': 0.0,
#  'ქႽ': 0.0,
#  'ქႭ': 0.0,
#  'ქი': 0.0,
#  'ქჳ': 0.0,
#  'ქჰ': 0.0,
#  'ქႾ': 0.0,
#  'ქჱ': 0.0,
#  'ქნ': 0.0,
#  'ქჂ': 0.0,
#  'ქႠ': 0.0,
#  'ქს': 0.0,
#  'ქႧ': 0.0,
#  'ქე': 0.0,
#  'ქქ': 0.0,
#  'ქჲ': 0.0,
#  'ქჶ': 0.0,
#  'ქჾ': 0.0,
#  'ქხ': 0.0,
#  'ქႲ': 0.0,
#  'ქდ': 0.0,
#  'ქႣ': 0.0,
#  'ქჵ': 0.0,
#  'ქႨ': 0.0,
#  'ჲႩ': 0.0,
#  'ჲჇ': 0.0,
#  'ჲშ': 0.0,
#  'ჲႼ': 0.0,
#  'ჲႽ': 0.0,
#  'ჲႭ': 0.0,
#  'ჲჳ': 0.0,
#  'ჲჰ': 0.0,
#  'ჲႾ': 0.0,
#  'ჲჱ': 0.0,
#  'ჲნ': 0.0,
#  'ჲჂ': 0.0,
#  'ჲႠ': 0.0,
#  'ჲს': 0.0,
#  'ჲႧ': 0.0,
#  'ჲე': 0.0,
#  'ჲქ': 0.0,
#  'ჲჲ': 0.0,
#  'ჲჶ': 0.0,
#  'ჲჾ': 0.0,
#  'ჲხ': 0.0,
#  'ჲႲ': 0.0,
#  'ჲჵ': 0.0,
#  'ჲႨ': 0.0,
#  'ჶႩ': 0.0,
#  'ჶჇ': 0.0,
#  'ჶშ': 0.0,
#  'ჶႼ': 0.0,
#  'ჶႽ': 0.0,
#  'ჶႭ': 0.0,
#  'ჶი': 0.0,
#  'ჶႹ': 0.0,
#  'ჶჳ': 0.0,
#  'ჶჰ': 0.0,
#  'ჶႾ': 0.0,
#  'ჶჱ': 0.0,
#  'ჶნ': 0.0,
#  'ჶჂ': 0.0,
#  'ჶႠ': 0.0,
#  'ჶს': 0.0,
#  'ჶႧ': 0.0,
#  'ჶე': 0.0,
#  'ჶქ': 0.0,
#  'ჶჲ': 0.0,
#  'ჶჶ': 0.0,
#  'ჶჾ': 0.0,
#  'ჶხ': 0.0,
#  'ჶႲ': 0.0,
#  'ჶდ': 0.0,
#  'ჶႣ': 0.0,
#  'ჶჵ': 0.0,
#  'ჶႨ': 0.0,
#  'ჾႩ': 0.0,
#  'ჾჇ': 0.0,
#  'ჾშ': 0.0,
#  'ჾႼ': 0.0,
#  'ჾႽ': 0.0,
#  'ჾႭ': 0.0,
#  'ჾი': 0.0,
#  'ჾႹ': 0.0,
#  'ჾჳ': 0.0,
#  'ჾჰ': 0.0,
#  'ჾႾ': 0.0,
#  'ჾჱ': 0.0,
#  'ჾნ': 0.0,
#  'ჾჂ': 0.0,
#  'ჾႠ': 0.0,
#  'ჾს': 0.0,
#  'ჾႧ': 0.0,
#  'ჾე': 0.0,
#  'ჾქ': 0.0,
#  'ჾჲ': 0.0,
#  'ჾჶ': 0.0,
#  'ჾჾ': 0.0,
#  'ჾხ': 0.0,
#  'ჾႲ': 0.0,
#  'ჾდ': 0.0,
#  'ჾჵ': 0.0,
#  'ჾႨ': 0.0,
#  'ხႩ': 0.0,
#  'ხჇ': 0.0,
#  'ხშ': 0.0,
#  'ხႼ': 0.0,
#  'ხႽ': 0.0,
#  'ხႭ': 0.0,
#  'ხი': 0.0,
#  'ხႹ': 0.0,
#  'ხჳ': 0.0,
#  'ხჰ': 0.0,
#  'ხႾ': 0.0,
#  'ხჱ': 0.0,
#  'ხნ': 0.0,
#  'ხႠ': 0.0,
#  'ხႧ': 0.0,
#  'ხე': 0.0,
#  'ხქ': 0.0,
#  'ხჲ': 0.0,
#  'ხჶ': 0.0,
#  'ხჾ': 0.0,
#  'ხხ': 0.0,
#  'ხႲ': 0.0,
#  'ხႣ': 0.0,
#  'ხჵ': 0.0,
#  'ხႨ': 0.0,
#  'ႲႩ': 0.0,
#  'ႲჇ': 0.0,
#  'Ⴒშ': 0.0,
#  'ႲႼ': 0.0,
#  'ႲႽ': 0.0,
#  'ႲႭ': 0.0,
#  'Ⴒი': 0.0,
#  'Ⴒჳ': 0.0,
#  'Ⴒჰ': 0.0,
#  'ႲႾ': 0.0,
#  'Ⴒჱ': 0.0,
#  'Ⴒნ': 0.0,
#  'ႲჂ': 0.0,
#  'ႲႠ': 0.0,
#  'Ⴒს': 0.0,
#  'ႲႧ': 0.0,
#  'Ⴒე': 0.0,
#  'Ⴒქ': 0.0,
#  'Ⴒჲ': 0.0,
#  'Ⴒჶ': 0.0,
#  'Ⴒჾ': 0.0,
#  'Ⴒხ': 0.0,
#  'ႲႲ': 0.0,
#  'Ⴒდ': 0.0,
#  'ႲႣ': 0.0,
#  'Ⴒჵ': 0.0,
#  'ႲႨ': 0.0,
#  'დჇ': 0.0,
#  'დშ': 0.0,
#  'დႼ': 0.0,
#  'დႽ': 0.0,
#  'დႭ': 0.0,
#  'დი': 0.0,
#  'დႹ': 0.0,
#  'დჰ': 0.0,
#  'დႾ': 0.0,
#  'დჱ': 0.0,
#  'დნ': 0.0,
#  'დჂ': 0.0,
#  'დႠ': 0.0,
#  'დႧ': 0.0,
#  'დე': 0.0,
#  'დჾ': 0.0,
#  'დხ': 0.0,
#  'დႲ': 0.0,
#  'დႣ': 0.0,
#  'დჵ': 0.0,
#  'ႣႩ': 0.0,
#  'ႣჇ': 0.0,
#  'Ⴃშ': 0.0,
#  'ႣႼ': 0.0,
#  'ႣႽ': 0.0,
#  'ႣႭ': 0.0,
#  'Ⴃი': 0.0,
#  'ႣႹ': 0.0,
#  'Ⴃჳ': 0.0,
#  'Ⴃჰ': 0.0,
#  'ႣႾ': 0.0,
#  'Ⴃჱ': 0.0,
#  'ႣჂ': 0.0,
#  'ႣႠ': 0.0,
#  'ႣႧ': 0.0,
#  'Ⴃე': 0.0,
#  'Ⴃქ': 0.0,
#  'Ⴃჲ': 0.0,
#  'Ⴃჶ': 0.0,
#  'Ⴃჾ': 0.0,
#  'ႣႲ': 0.0,
#  'Ⴃდ': 0.0,
#  'ႣႣ': 0.0,
#  'ႣႨ': 0.0,
#  'ჵႩ': 0.0,
#  'ჵჇ': 0.0,
#  'ჵშ': 0.0,
#  'ჵႼ': 0.0,
#  'ჵႽ': 0.0,
#  'ჵႭ': 0.0,
#  'ჵႹ': 0.0,
#  'ჵჳ': 0.0,
#  'ჵჰ': 0.0,
#  'ჵႾ': 0.0,
#  'ჵჱ': 0.0,
#  'ჵნ': 0.0,
#  'ჵႠ': 0.0,
#  'ჵს': 0.0,
#  'ჵႧ': 0.0,
#  'ჵე': 0.0,
#  'ჵქ': 0.0,
#  'ჵჲ': 0.0,
#  'ჵჶ': 0.0,
#  'ჵჾ': 0.0,
#  'ჵხ': 0.0,
#  'ჵႲ': 0.0,
#  'ჵჵ': 0.0,
#  'ႨႼ': 0.0,
#  'ႨႽ': 0.0,
#  'ႨႭ': 0.0,
#  'Ⴈი': 0.0,
#  'ႨႹ': 0.0,
#  'Ⴈჰ': 0.0,
#  'Ⴈნ': 0.0,
#  'Ⴈქ': 0.0,
#  'Ⴈჶ': 0.0,
#  'Ⴈჾ': 0.0,
#  'Ⴈხ': 0.0,
#  'Ⴈდ': 0.0,
#  'ႨႣ': 0.0,
#  'ႨႨ': 0.0}

# %%
m_freq2_perms = my_MCMC(list(m_freq2.keys()),list(m_freq2.values()),int(len(message)/2),1/2,5,100,10)

# %%
m1 = ''
for i in range(0,len(message),2):
    if message[i:i+2] in msymbols2:
        m1 += list(wp_freq2s.keys())[list(m_freq2.keys()).index(message[i:i+2])]
    else: m1 += message[i:i+2]
m1 += '\n'
            
m2 = ''
k1 = 0
for i in range(0,len(message),2):
    if message[i:i+2] in msymbols2:
        m2 += list(wp_freq2s.keys())[list(m_freq2_perms[k1]).index(message[i:i+2])]
        k1 += 1
    else: 
        m2 += message[i:i+2]
m2 += '\n'

# %% [markdown]
# ### Сравним получившиеся результаты

# %%
print('Оригинальное сообщение:\n')
print(message)
print('\n\nПростая замена биграммов:\n')
print(m1)
print('\nЗамена биграммов с применением MCMC сэмплирования:\n')
print(m2)
# Out:
# Оригинальное сообщение:
#
# დჳჵჂႨშႼႨშჂხჂჲდႨსႹႭჾႣჵისႼჰႨჂჵჂႨႲႹႧჲჂႨსႹႭჾႣჵისႼჰႨჲდႩჳჲႨჇႨႠჲႹქႹႨჳႹႹჱჶდსჂႽႨႩႹჲႹႭႼჰႨჵდქႩႹႨႲႭႹႧჂჲႣჲიႨჳႩႹႭდდႨშჳდქႹႨშႼႨშჳდႨჳხდჵႣჵჂႨႲႭႣშჂჵისႹႨჂႨႲႹჵჇႧჂჲდႨჾႣႩჳჂჾႣჵისႼჰႨჱႣჵჵႨეႣႨႲႹჳჵდხსდდႨႧდჲშდႭჲႹდႨეႣხႣსჂდႨႩჇႭჳႣႨႾႹჲႽႨႩႹსდႧსႹႨႽႨსჂႧდქႹႨსდႨႹჱდჶႣნ
#
#
# Простая замена биграммов:
#
# акране ди огомкое гоно гор м итери истен п о сойскотжелетьна нл ре зелпоа е  смоало    т чатан но ер вь ал к бнели н р ура  рои ностас  онкапр вгоя ва п о сбы п ев   осемодвельдевоолниетдак й поовлоняа тоо там  ктозаилнако влау аз
#
#
# Замена биграммов с применением MCMC сэмплирования:
#
# емакако аного  нь  п тльеми пр гоймоствоь  силв васксккост ри тьат бжеем ист ч р г оа л нианй стен згоковеерритеомниняя  вловесткоомойат г о ди  нзаск нетломоя  гракоу м  оламоовта з нва се теодстанра  емно пстк илть дилра пв  уст
